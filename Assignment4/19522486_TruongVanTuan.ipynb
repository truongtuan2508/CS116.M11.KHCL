# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import imutils
import cv2 
from google.colab.patches import cv2_imshow
from sklearn.decomposition import PCA

# %% [markdown]
# Bước 1+2:

# %%
image = cv2.imread("/content/a.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow( gray)
# Out:
# <PIL.Image.Image image mode=L size=700x700 at 0x7F63D3749910>

# %%
gray.shape
# Out:
# (700, 700)

# %% [markdown]
# Bước 3:

# %%
pca = PCA(32)
new_img = pca.fit(gray)
comonments = pca.transform(gray)

# %%
comonments.shape
# Out:
# (700, 32)

# %% [markdown]
# Bước 4:

# %%
recover_img = pca.inverse_transform(comonments)

# %%
cv2_imshow(recover_img)
# Out:
# <PIL.Image.Image image mode=L size=700x700 at 0x7F63D3712810>

# %%
recover_img.shape
# Out:
# (700, 700)
